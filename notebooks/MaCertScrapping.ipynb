# %%
# !pip install requests beautifulsoup4 pandas openpyxl
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.2.3-py3-none-any.whl.metadata (2.7 kB)
# Downloading XlsxWriter-3.2.3-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.3

# %% [markdown]
# URL du rapport :
# https://www.dgssi.gov.ma/fr/bulletins-securite

# %% [markdown]
# #WEB SCRAPPING DGSSI

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import os
import time
from urllib.parse import urljoin

# %%
import re
import time
import pandas as pd
from functools import wraps
import os

# %%
# Base URL of the website
BASE_URL = "https://www.dgssi.gov.ma"

# %%
def scrape_report_details(url):
    print(f"\n----- SCRAPING REPORT: {url} -----")
    try:
        # Send GET request to the report page with a timeout
        print("Sending request to report page...")
        response = requests.get(url, timeout=10)
        print(f"Response status code: {response.status_code}")

        soup = BeautifulSoup(response.content, "html.parser")

        # TESTING TIP 2: Save HTML for debugging
        filename = f"debug_page_{url.split('/')[-1].replace('/', '_')}.html"
        with open(filename, "w", encoding="utf-8") as f:
            f.write(response.text)
        print(f"Saved HTML to {filename}")

        # Initialize a dictionary to store the report data
        report_data = {"URL": url}

        # Helper function to clean field values
        def clean_field_value(text, field_name):
            """Remove field name from the value if present"""
            if field_name in text:
                return text.replace(field_name, "").strip()
            return text.strip()

        # Extract Title from the page (from h1 or the table)
        print("Extracting title...")
        title_tag = soup.find("h1")
        if title_tag:
            print(f"Found title in h1: {title_tag.text.strip()}")
            report_data["Title"] = title_tag.text.strip()
        else:
            print("No h1 title found, looking in table...")
            title_row = soup.find("td", text="Titre") or soup.find("th", text="Titre")
            if title_row:
                title_tag = title_row.find_next("td")
                if title_tag:
                    title_text = clean_field_value(title_tag.text.strip(), "Titre")
                    print(f"Found title in table: {title_text}")
                    report_data["Title"] = title_text
                else:
                    print("No title found in table")
                    report_data["Title"] = "No Title"
            else:
                print("No title row found in table")
                report_data["Title"] = "No Title"

        # Extract Reference Number
        print("Extracting reference number...")
        ref_row = soup.find("td", text="Numéro de Référence") or soup.find("th", text="Numéro de Référence")
        if ref_row:
            print("Found reference row")
            ref_number = ref_row.find_next("td")
            if ref_number:
                ref_text = clean_field_value(ref_number.text.strip(), "Numéro de Référence")
                print(f"Reference number: {ref_text}")
                report_data["Reference"] = ref_text
            else:
                print("No reference number found")
                report_data["Reference"] = "No Reference"
        else:
            print("No reference row found")
            report_data["Reference"] = "No Reference"

        # Extract Publication Date
        print("Extracting publication date...")
        date_row = soup.find("td", text="Date de publication") or soup.find("th", text="Date de publication")
        if date_row:
            print("Found date row")
            pub_date = date_row.find_next("td")
            if pub_date:
                pub_date_text = clean_field_value(pub_date.text.strip(), "Date de publication")
                print(f"Publication date: {pub_date_text}")
                report_data["Publication Date"] = pub_date_text
            else:
                print("No publication date found")
                report_data["Publication Date"] = "No Date"
        else:
            print("No date row found")
            report_data["Publication Date"] = "No Date"

        # Extract Risk Level
        print("Extracting risk level...")
        risk_row = soup.find("td", text="Niveau de Risque") or soup.find("th", text="Niveau de Risque")
        if risk_row:
            print("Found risk level row")
            risk_level = risk_row.find_next("td")
            if risk_level:
                risk_text = clean_field_value(risk_level.text.strip(), "Niveau de Risque")
                print(f"Risk level: {risk_text}")
                report_data["Risk Level"] = risk_text
            else:
                print("No risk level found")
                report_data["Risk Level"] = "No Risk Level"
        else:
            print("No risk level row found")
            report_data["Risk Level"] = "No Risk Level"

        # Extract Impact Level
        print("Extracting impact level...")
        impact_row = soup.find("td", text="Niveau d'Impact") or soup.find("th", text="Niveau d'Impact")
        if impact_row:
            print("Found impact level row")
            impact_level = impact_row.find_next("td")
            if impact_level:
                impact_text = clean_field_value(impact_level.text.strip(), "Niveau d'Impact")
                print(f"Impact level: {impact_text}")
                report_data["Impact Level"] = impact_text
            else:
                print("No impact level found")
                report_data["Impact Level"] = "No Impact Level"
        else:
            print("No impact level row found")
            report_data["Impact Level"] = "No Impact Level"

        # Extract Affected Systems
        print("Extracting affected systems...")
        systems_header = soup.find(string=lambda text: text and "Systèmes affectés" in text)
        if systems_header:
            print("Found systems header")
            # Try to find nearby list items or content
            systems_ul = systems_header.find_next("ul")
            if systems_ul:
                systems = [clean_field_value(li.text.strip(), "Systèmes affectés") for li in systems_ul.find_all("li")]
                print(f"Found {len(systems)} affected systems in list")
                report_data["Affected Systems"] = ", ".join(systems)
            else:
                # Try an alternative approach if no list found
                print("No list found, looking for paragraph...")
                next_p = systems_header.find_next("p")
                if next_p:
                    systems_text = clean_field_value(next_p.text.strip(), "Systèmes affectés")
                    print(f"Found systems in paragraph: {systems_text}")
                    report_data["Affected Systems"] = systems_text
                else:
                    print("No systems paragraph found")
                    report_data["Affected Systems"] = "No Affected Systems"
        else:
            print("No systems header found")
            report_data["Affected Systems"] = "No Affected Systems"

        # Extract Vulnerability Summary if available
        print("Extracting vulnerability summary...")
        summary_header = soup.find(string=lambda text: text and "Bilan de la vulnérabilité" in text)
        if summary_header:
            print("Found summary header")
            summary_div = summary_header.find_next("div") or summary_header.find_next("p")
            if summary_div:
                summary_text = clean_field_value(summary_div.text.strip(), "Bilan de la vulnérabilité")
                print(f"Found summary text (first 50 chars): {summary_text[:50]}...")
                report_data["Vulnerability Summary"] = summary_text
            else:
                print("No summary text found")
                report_data["Vulnerability Summary"] = "No Summary"
        else:
            print("No summary header found")
            report_data["Vulnerability Summary"] = "No Summary"

        # Extract Solution if available
        print("Extracting solution...")
        solution_header = soup.find(string=lambda text: text and "Solution" in text)
        if solution_header:
            print("Found solution header")
            solution_div = solution_header.find_next("div") or solution_header.find_next("p")
            if solution_div:
                solution_text = clean_field_value(solution_div.text.strip(), "Solution")
                print(f"Found solution text (first 50 chars): {solution_text[:50]}...")
                report_data["Solution"] = solution_text
            else:
                print("No solution text found")
                report_data["Solution"] = "No Solution"
        else:
            print("No solution header found")
            report_data["Solution"] = "No Solution"

        print("Extraction completed for this report")
        return report_data

    except Exception as e:
        print(f"ERROR scraping {url}: {e}")
        return {"URL": url, "Error": str(e), "Title": "Failed to scrape"}

# %%
# Function to scrape report URLs from the main bulletins page
def scrape_report_urls(save_to_file=True):
    print("\n----- SCRAPING REPORT URLS -----")
    # Try this URL instead
    url = "https://www.dgssi.gov.ma/fr/bulletins-securite"  # Updated URL
    print(f"Requesting main page: {url}")

    try:
        response = requests.get(url, timeout=10)
        print(f"Response status code: {response.status_code}")
        # Add after the response line in scrape_report_urls
        print(f"Response content preview: {response.text[:500]}...")

        soup = BeautifulSoup(response.content, "html.parser")
        print("Parsing response HTML...")

        # Extract all report links (looking for links to bulletin pages)
        report_links = []

        # Look for cards or containers with links
        print("Looking for bulletin links...")
        for link in soup.find_all("a", href=True):
            href = link["href"]

            # Check if it's a bulletin link
            if "/fr/bulletin" in href or "/bulletins/" in href:
                # Make absolute URL if it's relative
                full_url = urljoin(BASE_URL, href)
                report_links.append(full_url)
                print(f"Found bulletin link: {full_url}")

        # Also check for "En savoir plus" links which might lead to reports
        print("Looking for 'En savoir plus' links...")
        for link in soup.find_all("a", class_="btn"):
            if link.get("href"):
                full_url = urljoin(BASE_URL, link["href"])
                if full_url not in report_links:
                    report_links.append(full_url)
                    print(f"Found 'En savoir plus' link: {full_url}")

        # Remove duplicates
        original_count = len(report_links)
        report_links = list(set(report_links))
        print(f"Removed {original_count - len(report_links)} duplicate URLs")
        print(f"Total unique report URLs found: {len(report_links)}")

        # Save URLs to a JSON file to avoid scraping again in the future
        if save_to_file:
            with open("report_urls.json", "w") as file:
                json.dump(report_links, file)
                print(f"Saved {len(report_links)} URLs to report_urls.json")

        return report_links

    except Exception as e:
        print(f"ERROR scraping report URLs: {e}")
        return []

# %%
# Function to read the saved URLs from the file
def load_report_urls():
    print("\n----- LOADING REPORT URLS -----")
    if os.path.exists("report_urls.json"):
        print("Found existing report_urls.json file")
        with open("report_urls.json", "r") as file:
            urls = json.load(file)
            print(f"Loaded {len(urls)} URLs from file")
            return urls
    else:
        print("No existing report_urls.json file found")
        print("Scraping URLs from website...")
        # If the file does not exist, scrape the URLs and save them
        return scrape_report_urls(save_to_file=True)

# %% [markdown]
# the correct code for scrapping without errors

# %%
import re
import time
import pandas as pd
from functools import wraps

def handle_errors(func):
    """Decorator to handle common scraping errors"""
    @wraps(func)
    def wrapper(*args, **kwargs):
        try:
            return func(*args, **kwargs)
        except Exception as e:
            print(f"Error in {func.__name__}: {str(e)}")
            return None
    return wrapper

def clean_text(text):
    """Clean text while preserving accents and removing control characters"""
    if not isinstance(text, str):
        return text

    # First replace problematic control characters
    text = re.sub(r'[\x00-\x08\x0b\x0c\x0e-\x1f\x7f]', ' ', text)

    # Replace special hyphens/dashes with normal ones
    text = re.sub(r'[\u2010-\u2015]', '-', text)

    # Remove other problematic Unicode characters while preserving accents
    text = re.sub(r'[\u2028\u2029]', ' ', text)  # Line/paragraph separators

    # Normalize newlines and multiple spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text


def main():
    print("\n============================================")
    print("STARTING DGSSI SECURITY BULLETINS SCRAPER")
    print("============================================\n")

    try:
        # Load or scrape the report URLs
        report_links = load_report_urls()
        if not report_links:
            print("ERROR: No report URLs found. Please check the website structure or connection.")
            return

        print(f"\nFinal list contains {len(report_links)} report URLs")

        # List to hold the scraped report data
        all_reports = []

        # Iterate through all the report links and scrape the individual report data
        for i, report_url in enumerate(report_links):
            print(f"\n[PROGRESS] Scraping report {i+1}/{len(report_links)}")
            report_data = scrape_report_details(report_url)
            if report_data:
                all_reports.append(report_data)
                print(f"Added report to dataset: {report_data.get('Title', 'Unknown Title')}")

                # Add a short delay to avoid overwhelming the server
                if i < len(report_links) - 1:
                    print("Waiting 1 second before next request...")
                    time.sleep(1)

        if not all_reports:
            print("ERROR: No reports were successfully scraped.")
            return

        # Convert to DataFrame
        print("\n----- CREATING DATAFRAME -----")
        df = pd.DataFrame(all_reports)
        print(f"Created DataFrame with {len(df)} rows and {len(df.columns)} columns")
        print(f"Columns: {', '.join(df.columns)}")

        # Reorder columns for better readability
        column_order = [
            "Title", "Reference", "Publication Date", "Risk Level",
            "Impact Level", "Affected Systems", "Vulnerability Summary",
            "Solution", "URL"
        ]

        # Only include columns that exist in the DataFrame
        columns_to_use = [col for col in column_order if col in df.columns]
        # Add any additional columns that weren't in the order list
        columns_to_use.extend(col for col in df.columns if col not in columns_to_use)
        df = df[columns_to_use]
        print(f"Reordered columns: {', '.join(columns_to_use)}")

        # Clean all text columns
        print("\n----- CLEANING DATA -----")
        for column in df.columns:
            if df[column].dtype == object:
                df[column] = df[column].apply(lambda x: clean_text(x) if isinstance(x, str) else x)

        # Save the data to Excel
        excel_filename = "rapports_dgssi_securite_cleaned.xlsx"
        print(f"\n----- SAVING DATA TO EXCEL -----")

        # Additional Excel writer parameters for robustness
        writer = pd.ExcelWriter(
            excel_filename,
            engine='xlsxwriter'

        )
        df.to_excel(writer, index=False)
        writer.close()

        print("\n============================================")
        print(f"SCRAPING COMPLETE: Data saved to '{excel_filename}'")
        print(f"Total reports scraped: {len(all_reports)}")
        print("============================================")

    except Exception as e:
        print(f"\nCRITICAL ERROR: {str(e)}")
        print("Scraping failed. Please check the error message above.")



    # Save the data to CSV instead of Excel
import pandas as pd  # Import pandas if not already done

csv_filename = "rapports_dgssi_securite_cleaned.csv"
print(f"\n----- SAVING DATA TO CSV -----")

# Assuming 'all_reports' contains your scraped data:
df = pd.DataFrame(all_reports)  # Create DataFrame from all_reports

# Save the DataFrame to a CSV file
df.to_csv(csv_filename, index=False)

print("\n============================================")
print(f"SCRAPING COMPLETE: Data saved to '{csv_filename}'")
print(f"Total reports scraped: {len(all_reports)}")
print("============================================")

if __name__ == "__main__":
    main()
# Out:
# ----- SAVING DATA TO CSV -----
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-238abf9d74e0> in <cell line: 0>()
#     126
#     127 # Assuming 'all_reports' contains your scraped data:
# --> 128 df = pd.DataFrame(all_reports)  # Create DataFrame from all_reports
#     129
#     130 # Save the DataFrame to a CSV file
#
# NameError: name 'all_reports' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil# Define the source and destination paths
source_path = '/content/rapports_dgssi_securite_cleaned.csv'
destination_dir = '/content/drive/MyDrive/MY TASKS/Data Driven/'
destination_path = destination_dir + 'rapports_dgssi_securite_cleaned.csv'

# Move the file
shutil.move(source_path, destination_path)

print(f"File moved to {destination_path}")
# Out:
# File moved to /content/drive/MyDrive/MY TASKS/Data Driven/rapports_dgssi_securite_cleaned.csv

# %% [markdown]
# #Fin

# %%
def main():
    print("\n============================================")
    print("STARTING DGSSI SECURITY BULLETINS SCRAPER")
    print("============================================\n")

    # Load or scrape the report URLs
    report_links = load_report_urls()
    print(f"\nFinal list contains {len(report_links)} report URLs")

    # TESTING TIP 1: Add this here to limit testing to just a few URLs
    # Uncomment the following line for testing with fewer URLs

    if not report_links:
        print("ERROR: No report URLs found. Please check the website structure or connection.")
        return

    # List to hold the scraped report data
    all_reports = []

    # Iterate through all the report links and scrape the individual report data
    for i, report_url in enumerate(report_links):
        print(f"\n[PROGRESS] Scraping report {i+1}/{len(report_links)}")
        report_data = scrape_report_details(report_url)
        all_reports.append(report_data)
        print(f"Added report to dataset: {report_data.get('Title', 'Unknown Title')}")

        # Add a short delay to avoid overwhelming the server
        if i < len(report_links) - 1:  # Don't sleep after the last request
            print(f"Waiting 1 second before next request...")
            time.sleep(1)

    # Convert the list of reports into a DataFrame
    print("\n----- CREATING DATAFRAME -----")
    df = pd.DataFrame(all_reports)
    print(f"Created DataFrame with {len(df)} rows and {len(df.columns)} columns")
    print(f"Columns: {', '.join(df.columns)}")

    # Reorder columns for better readability
    column_order = [
        "Title", "Reference", "Publication Date", "Risk Level",
        "Impact Level", "Affected Systems", "Vulnerability Summary",
        "Solution", "URL"
    ]

    # Only include columns that exist in the DataFrame
    columns_to_use = [col for col in column_order if col in df.columns]

    # Add any additional columns that weren't in the order list
    for col in df.columns:
        if col not in columns_to_use:
            columns_to_use.append(col)

    df = df[columns_to_use]
    print(f"Reordered columns: {', '.join(columns_to_use)}")

    # Save the data to CSV instead of Excel for better handling
    csv_filename = "rapports_dgssi_securite_cleaned.csv"
    print(f"\n----- SAVING DATA TO CSV -----")
    df.to_csv(csv_filename, index=False)

    print("\n============================================")
    print(f"SCRAPING COMPLETE: Data saved to '{csv_filename}'")
    print(f"Total reports scraped: {len(all_reports)}")
    print("============================================")

if __name__ == "__main__":
    main()
# Out:
# ============================================
# STARTING DGSSI SECURITY BULLETINS SCRAPER
# ============================================
#
#
# ----- LOADING REPORT URLS -----
# No existing report_urls.json file found
# Scraping URLs from website...
#
# ----- SCRAPING REPORT URLS -----
# Requesting main page: https://www.dgssi.gov.ma/fr/bulletins-securite
# Response status code: 200
# Response content preview: <!DOCTYPE html><html lang="fr" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# schema: http://schema.org/ sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# "><head><meta charset="utf-8" /><link rel="canonical" href="https://www.dgssi.gov.ma/fr/bulletins...
# Parsing response HTML...
# Looking for bulletin links...
# Found bulletin link: https://www.dgssi.gov.ma/index.php/fr/bulletins-securite
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins-securite
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins-securite
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-les-routeurs-asus
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-les-routeurs-asus
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-serveur-ssh-derlangotp
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-serveur-ssh-derlangotp
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-plugin-instawp-connect-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-plugin-instawp-connect-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-plugin-everest-forms-pour-wordpress-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-plugin-everest-forms-pour-wordpress-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-dans-sonicwall-connect-tunnel
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-dans-sonicwall-connect-tunnel
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-des-produits-de-cisco-7
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-des-produits-de-cisco-7
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-les-produits-apple-3
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-les-produits-apple-3
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/oracle-critical-patch-update-du-mois-avril-2025
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/oracle-critical-patch-update-du-mois-avril-2025
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-mozilla-firefox-et-thunderbird-2
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-mozilla-firefox-et-thunderbird-2
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-google-chrome-23
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-google-chrome-23
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-apache-roller
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-apache-roller
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/post-exploitation-attaque-des-liens-symboliques-cible-des-dispositifs-fortigate
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/post-exploitation-attaque-des-liens-symboliques-cible-des-dispositifs-fortigate
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-le-plugin-everest-forms-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-le-plugin-everest-forms-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-le-plugin-suretriggers-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-le-plugin-suretriggers-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-sonicwall-netextender
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-sonicwall-netextender
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-les-produits-palo-alto-2
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-les-produits-palo-alto-2
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-le-navigateur-google-chrome-5
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-le-navigateur-google-chrome-5
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-ivanti
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-ivanti
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-juniper-6
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-juniper-6
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-whatsapp-sur-windows
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-whatsapp-sur-windows
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-siemens-3
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-siemens-3
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-plusieurs-produits-microsoft-patch-tuesday-avril-2025
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-plusieurs-produits-microsoft-patch-tuesday-avril-2025
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-fortinet-fortiswitch
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-fortinet-fortiswitch
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-plusieurs-produits-dadobe-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-plusieurs-produits-dadobe-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-microsoft-browser-patch-tuesday-avril-2025
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-microsoft-browser-patch-tuesday-avril-2025
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-microsoft-azure-patch-tuesday-avril-2025
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-microsoft-azure-patch-tuesday-avril-2025
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les
1
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-moxa
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-dell-openmanage-server-administrator-omsa
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-le-plugin-updraftplus-backup-migration-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-les-routeurs-asus-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-truenas-core
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-palo-alto-pan-os-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-apache-traffic-control
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-le-package-npm-systeminformation
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-loutil-dadministration-webmin
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-adobe-coldfusion
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-apache-tomcat
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/le-rat-remcos
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-sophos-firewall
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-les-produits-beyondtrust
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-google-chrome-17
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-les-produits-fortigate
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-les-produits-siemens
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-apache-tomcat-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-les-routeurs-sharp
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-les-produits-hitachi
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-le-client-de-messagerie-mozilla-thunderbird-1
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-plusieurs-produits-dapple-4
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-des-produits-de-dell
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-plugin-hunk-companion-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-apache-struts
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-plusieurs-produits-dadobe-18
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-des-produits-de-schneider-electric
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-le-navigateur-google-chrome-31
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-ivanti-cloud-services-application
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-microsoft-system-center-patch-tuesday-decembre-2024
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-le-navigateur-microsoft-edge-patch-tuesday-decembre-2024
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-microsoft-windows-esu-patch-tuesday-decembre-2024
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-microsoft-windows-patch-tuesday-decembre-2024
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-microsoft-office-patch-tuesday-decembre-2024
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-le-plugin-wpforms-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-plusieurs-produits-sap-16
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-plugin-wp-umbrella-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-des-produits-qnap-2
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-tp-link-archer-axe75
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-sonicwall-sma100-ssl-vpn
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-les-produits-cisco-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-dans-solarwinds-platform
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-dans-google-chrome
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-cisco-adaptive-security-appliance-asa
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-veeam-service-provider-console
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/dcrat-rat
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-google-android-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/site-frauduleux-collectant-des-informations-sensibles-liees-laide-sociale-directe
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-ivanti-endpoint-manager-mobile-epmm
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-hpe-insight-remote-support
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-pare-feux-zyxel
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-les-produits-gitlab-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-jenkins-1
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-zabbix
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-nvidia-ufm
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-projectsend
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-plusieurs-produits-microsoft
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-industriels-de-schneider-electric-2
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-mozilla-4
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-php
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-vmware-aria-operations-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-plugin-anti-spam-cleantalk-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-palo-alto-globalprotect-app-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-qnap-notes-station-3
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-7-zip
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-ibm-16
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-le-plugin-fluentsmtp-pour-wordpress
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-dans-winzip
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-les-routeurs-d-link
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-anydesk
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-php-3
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-kubernetes
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-atlassian-4
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-trend-micro-deep-security-agent
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-affectant-laravel
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-le-cms-drupal-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-apache-traffic-server-ats
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dexecution-de-code-distance-linterface-de-gestion-de-pan-ossuite
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-critique-dans-oracle-agile-product-lifecycle-management
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-nvidia-0
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-le-navigateur-google-chrome-30
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-plusieurs-produits-dapple-3
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/des-vulnerabilites-critiques-affectant-vmware-vcenter-et-cloud-sont-activement-exploitees
# Found bulletin link: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-affectant-postgresql
# ...
# Extracting reference number...
# Found reference row
# Reference number: 48542607/24
# Extracting publication date...
# Found date row
# Publication date: 26 juillet 2024
# Extracting risk level...
# Found risk level row
# Risk level: Critique
# Extracting impact level...
# Found impact level row
# Impact level: Critique
# Extracting affected systems...
# Found systems header
# Found 2 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Siemens annonce la correction de deux vulnérabilit...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer aux bulletins de sécurité de S...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités critiques affectant des produits de Siemens
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1508/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilite-dans-le-cms-drupal-4 -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilite-dans-le-cms-drupal-4.html
# Extracting title...
# Found title in h1: Vulnérabilité dans le CMS Drupal
# Extracting reference number...
# Found reference row
# Reference number: 53442103 /25
# Extracting publication date...
# Found date row
# Publication date: 21 mars 2025
# Extracting risk level...
# Found risk level row
# Risk level: Important
# Extracting impact level...
# Found impact level row
# Impact level: Important
# Extracting affected systems...
# Found systems header
# Found 4 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Une vulnérabilité a été corrigée dans le CMS Drupa...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité Drupal...
# Extraction completed for this report
# Added report to dataset: Vulnérabilité dans le CMS Drupal
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1509/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-les-produits-sap-1 -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-critiques-dans-les-produits-sap-1.html
# Extracting title...
# Found title in h1: Vulnérabilités critiques dans les produits SAP
# Extracting reference number...
# Found reference row
# Reference number: 44831611/23
# Extracting publication date...
# Found date row
# Publication date: 16 novembre 2023
# Extracting risk level...
# Found risk level row
# Risk level: Critique
# Extracting impact level...
# Found impact level row
# Impact level: Critique
# Extracting affected systems...
# Found systems header
# Found 18 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): SAP annonce la disponibilité d’une mise à jour de ...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité SAP du...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités critiques dans les produits SAP
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1510/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-les-produits-juniper-2 -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-dans-les-produits-juniper-2.html
# Extracting title...
# Found title in h1: Vulnérabilités dans les produits Juniper
# Extracting reference number...
# Found reference row
# Reference number: 45531201/24
# Extracting publication date...
# Found date row
# Publication date: 12 janvier 2024
# Extracting risk level...
# Found risk level row
# Risk level: Important
# Extracting impact level...
# Found impact level row
# Impact level: Important
# Extracting affected systems...
# Found systems header
# Found 6 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Juniper annonce la correction de plusieurs vulnéra...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité Junipe...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités dans les produits Juniper
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1511/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-apple-xcode -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-dans-apple-xcode.html
# Extracting title...
# Found title in h1: VULNÉRABILITÉS DANS APPLE XCODE
# Extracting reference number...
# Found reference row
# Reference number: 39040411/22
# Extracting publication date...
# Found date row
# Publication date: 04 novembre 2022
# Extracting risk level...
# Found risk level row
# Risk level: Modéré
# Extracting impact level...
# Found impact level row
# Impact level: Modéré
# Extracting affected systems...
# Found systems header
# Found 3 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Apple annonce la correction de plusieurs vulnérabi...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité Apple ...
# Extraction completed for this report
# Added report to dataset: VULNÉRABILITÉS DANS APPLE XCODE
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1512/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilitesaffectant-leclient-de-messagerie-mozilla-thunderbird -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilitesaffectant-leclient-de-messagerie-mozilla-thunderbird.html
# Extracting title...
# Found title in h1: Vulnérabilitésaffectant leclient de messagerie Mozilla Thunderbird
# Extracting reference number...
# Found reference row
# Reference number: 43580509/23
# Extracting publication date...
# Found date row
# Publication date: 05 septembre 2023
# Extracting risk level...
# Found risk level row
# Risk level: Important
# Extracting impact level...
# Found impact level row
# Impact level: Important
# Extracting affected systems...
# Found systems header
# Found 3 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Mozilla Foundation annonce la disponibilité d'une ...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité de Moz...
# Extraction completed for this report
# Added report to dataset: Vulnérabilitésaffectant leclient de messagerie Mozilla Thunderbird
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1513/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-openssl-0 -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-dans-openssl-0.html
# Extracting title...
# Found title in h1: Vulnérabilités dans OpenSSL
# Extracting reference number...
# Found reference row
# Reference number: 40200802/23
# Extracting publication date...
# Found date row
# Publication date: 08 février 2023
# Extracting risk level...
# Found risk level row
# Risk level: Modéré
# Extracting impact level...
# Found impact level row
# Impact level: Modéré
# Extracting affected systems...
# Found systems header
# Found 3 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): OpenSSL a publié un avis de sécurité pour corriger...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité OpenSS...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités dans OpenSSL
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1514/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-microsoft-office-patch-tuesday-septembre-2024 -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-critiques-dans-microsoft-office-patch-tuesday-septembre-2024.html
# Extracting title...
# Found title in h1: Vulnérabilités critiques dans Microsoft Office (Patch Tuesday Septembre 2024)
# Extracting reference number...
# Found reference row
# Reference number: 49291109/24
# Extracting publication date...
# Found date row
# Publication date: 11 septembre 2024
# Extracting risk level...
# Found risk level row
# Risk level: Critique
# Extracting impact level...
# Found impact level row
# Impact level: Critique
# Extracting affected systems...
# Found systems header
# Found 21 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Microsoft annonce la correction de plusieurs vulné...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité Micros...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités critiques dans Microsoft Office (Patch Tuesday Septembre 2024)
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1515/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-vmware-vrealize-log-insight -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-critiques-affectant-vmware-vrealize-log-insight.html
# Extracting title...
# Found title in h1: Vulnérabilités critiques affectant VMware vRealize Log Insight
# Extracting reference number...
# Found reference row
# Reference number: 39952501/23
# Extracting publication date...
# Found date row
# Publication date: 25 janvier 2023
# Extracting risk level...
# Found risk level row
# Risk level: Important
# Extracting impact level...
# Found impact level row
# Impact level: Important
# Extracting affected systems...
# Found systems header
# Found 1 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): VMware annonce la correction de vulnérabilités cri...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité de VMw...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités critiques affectant VMware vRealize Log Insight
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1516/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-dans-google-chrome-14 -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-dans-google-chrome-14.html
# Extracting title...
# Found title in h1: Vulnérabilités dans Google Chrome
# Extracting reference number...
# Found reference row
# Reference number: 47861206/24
# Extracting publication date...
# Found date row
# Publication date: 12 juin 2024
# Extracting risk level...
# Found risk level row
# Risk level: Important
# Extracting impact level...
# Found impact level row
# Impact level: Important
# Extracting affected systems...
# Found systems header
# Found 2 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Google a publié des mises à jour de sécurité pour ...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité Google...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités dans Google Chrome
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1517/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-dans-veeam-service-provider-console -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-critiques-dans-veeam-service-provider-console.html
# Extracting title...
# Found title in h1: Vulnérabilités critiques dans Veeam Service Provider Console
# Extracting reference number...
# Found reference row
# Reference number: 51300412/24
# Extracting publication date...
# Found date row
# Publication date: 04 décembre 2024
# Extracting risk level...
# Found risk level row
# Risk level: Critique
# Extracting impact level...
# Found impact level row
# Impact level: Critique
# Extracting affected systems...
# Found systems header
# Found 1 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Deux vulnérabilités critiques ont été corrigées da...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer au bulletin de sécurité Veeam ...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités critiques dans Veeam Service Provider Console
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1518/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-affectant-microsoft-windows-esu-patch-tuesday-mars-2025 -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-affectant-microsoft-windows-esu-patch-tuesday-mars-2025.html
# Extracting title...
# Found title in h1: Vulnérabilités affectant Microsoft Windows ESU (Patch Tuesday Mars 2025)
# Extracting reference number...
# Found reference row
# Reference number: 53181203/25
# Extracting publication date...
# Found date row
# Publication date: 12 mars 2025
# Extracting risk level...
# Found risk level row
# Risk level: Important
# Extracting impact level...
# Found impact level row
# Impact level: Critique
# Extracting affected systems...
# Found systems header
# Found 10 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Microsoft annonce la correction de plusieurs vulné...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez se référer aux bulletins de sécurité de M...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités affectant Microsoft Windows ESU (Patch Tuesday Mars 2025)
# Waiting 1 second before next request...
#
# [PROGRESS] Scraping report 1519/1519
#
# ----- SCRAPING REPORT: https://www.dgssi.gov.ma/fr/bulletins/vulnerabilites-critiques-affectant-le-plugin-forminator-pour-wordpress -----
# Sending request to report page...
# Response status code: 200
# Saved HTML to debug_page_vulnerabilites-critiques-affectant-le-plugin-forminator-pour-wordpress.html
# Extracting title...
# Found title in h1: Vulnérabilités critiques affectant le plugin «Forminator» pour WordPress
# Extracting reference number...
# Found reference row
# Reference number: 47102204/24
# Extracting publication date...
# Found date row
# Publication date: 22 avril 2024
# Extracting risk level...
# Found risk level row
# Risk level: Critique
# Extracting impact level...
# Found impact level row
# Impact level: Critique
# Extracting affected systems...
# Found systems header
# Found 1 affected systems in list
# Extracting vulnerability summary...
# Found summary header
# Found summary text (first 50 chars): Wordpress annonce la correction de trois vulnérabi...
# Extracting solution...
# Found solution header
# Found solution text (first 50 chars): Veuillez-vous référer à la page de mise à jour de ...
# Extraction completed for this report
# Added report to dataset: Vulnérabilités critiques affectant le plugin «Forminator» pour WordPress
#
# ----- CREATING DATAFRAME -----
# Created DataFrame with 1519 rows and 9 columns
# Columns: URL, Title, Reference, Publication Date, Risk Level, Impact Level, Affected Systems, Vulnerability Summary, Solution
# Reordered columns: Title, Reference, Publication Date, Risk Level, Impact Level, Affected Systems, Vulnerability Summary, Solution, URL
#
# ----- SAVING DATA TO CSV -----
#
# ============================================
# SCRAPING COMPLETE: Data saved to 'rapports_dgssi_securite_cleaned.csv'
# Total reports scraped: 1519
# ============================================
